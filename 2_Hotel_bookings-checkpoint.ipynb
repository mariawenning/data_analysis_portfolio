# %%
import pandas as pd
bookings = pd.read_csv(r'C:\Users\Masha\Downloads\2_bookings.csv', sep = ';')
bookings_head = bookings.head(7)
bookings_head
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
bookings.shape
# Out:
# (119390, 21)

# %%
bookings.dtypes
# Out:
# Hotel                         object
# Is Canceled                    int64
# Lead Time                      int64
# arrival full date             object
# Arrival Date Year              int64
# Arrival Date Month            object
# Arrival Date Week Number       int64
# Arrival Date Day of Month      int64
# Stays in Weekend nights        int64
# Stays in week nights           int64
# stays total nights             int64
# Adults                         int64
# Children                     float64
# Babies                         int64
# Meal                          object
# Country                       object
# Reserved Room Type            object
# Assigned room type            object
# customer type                 object
# Reservation Status            object
# Reservation status_date       object
# dtype: object

# %%
def replace_space_and_capital(name):
    new_name = name.replace(' ', '_').lower()
    return new_name

# %%
bookings.rename(columns = replace_space_and_capital)
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# 5       Resort Hotel            0         14        2015-07-01
# 6       Resort Hotel            0          0        2015-07-01
# 7       Resort Hotel            0          9        2015-07-01
# 8       Resort Hotel            1         85        2015-07-01
# 9       Resort Hotel            1         75        2015-07-01
# 10      Resort Hotel            1         23        2015-07-01
# 11      Resort Hotel            0         35        2015-07-01
# 12      Resort Hotel            0         68        2015-07-01
# 13      Resort Hotel            0         18        2015-07-01
# ...

# %%
def replace_space_and_capital(var):
    var = var.replace(' ','_').lower()
    return (var)

# %%
bookings = bookings.rename(columns = replace_space_and_capital)
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
all_lead_time=bookings.lead_time.sum()
all_lead_time
# Out:
# 12417923

# %%
top_5 = (bookings
         .query("is_canceled == '0'")
         .groupby('country', as_index = False)
         .agg({'is_canceled' : 'count'})
         .sort_values('is_canceled', ascending = False))
top_5.head()
# Out:
#     country  is_canceled
# 125     PRT        21071
# 57      GBR         9676
# 54      FRA         8481
# 50      ESP         6391
# 42      DEU         6069

# %%
round(bookings.query("hotel == 'City Hotel'").stays_total_nights.mean(),2)
# Out:
# 2.98

# %%
round(bookings.query("hotel == 'Resort Hotel'").stays_total_nights.mean(),2)
# Out:
# 4.32

# %%
#alternative_solution
bookings.groupby('hotel').agg({'stays_total_nights' : 'mean'}).round(2)
# Out:
#               stays_total_nights
# hotel
# City Hotel                  2.98
# Resort Hotel                4.32

# %%
bookings.query("assigned_room_type != reserved_room_type" ).shape
# Out:
# (14917, 21)

# %%
bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 21 columns):
# hotel                        119390 non-null object
# is_canceled                  119390 non-null int64
# lead_time                    119390 non-null int64
# arrival_full_date            119390 non-null object
# arrival_date_year            119390 non-null int64
# arrival_date_month           119390 non-null object
# arrival_date_week_number     119390 non-null int64
# arrival_date_day_of_month    119390 non-null int64
# stays_in_weekend_nights      119390 non-null int64
# stays_in_week_nights         119390 non-null int64
# stays_total_nights           119390 non-null int64
# adults                       119390 non-null int64
# children                     119386 non-null float64
# babies                       119390 non-null int64
# meal                         119390 non-null object
# country                      118902 non-null object
# ...

# %%
bookings.query("arrival_date_year == 2016").arrival_date_month.value_counts().sort_values(ascending = False)
# Out:
# May         6313
# April       5661
# June        5647
# July        5313
# March       4970
# August      4925
# February    4177
# January     3681
# Name: arrival_date_month, dtype: int64

# %%
bookings.query("arrival_date_year == 2017").arrival_date_month.value_counts().sort_values(ascending = False)
# Out:
# May         6313
# April       5661
# June        5647
# July        5313
# March       4970
# August      4925
# February    4177
# January     3681
# Name: arrival_date_month, dtype: int64

# %%
bookings.query("is_canceled == '1' & arrival_date_year == 2015").groupby('arrival_date_year')['arrival_date_month'].value_counts().sort_values(ascending = False)
# Out:
# arrival_date_year  arrival_date_month
# 2015               September             2094
#                    October               1732
#                    August                1598
#                    July                  1259
#                    December               973
#                    November               486
# Name: arrival_date_month, dtype: int64

# %%
bookings[['adults', 'children', 'babies']].head()
# Out:
#    adults  children  babies
# 0       2       0.0       0
# 1       2       0.0       0
# 2       1       0.0       0
# 3       1       0.0       0
# 4       2       0.0       0

# %%
bookings[['adults', 'children', 'babies']].mean().idxmax()
# Out:
# 'adults'

# %%
bookings['total_kids'] = bookings.children + bookings.babies
bookings.total_kids.max()
# Out:
# 10.0

# %%
bookings.groupby('hotel').agg({'total_kids' : 'mean'})
# Out:
#               total_kids
# hotel
# City Hotel      0.096311
# Resort Hotel    0.142586

# %%
bookings.groupby('hotel').total_kids.mean().round(2).idxmax()
# Out:
# 'Resort Hotel'

# %%
bookings['has_kids'] = bookings.total_kids > 0

# %%
with_kids = bookings.query("is_canceled == '1' & has_kids == True") \
    .groupby('has_kids', as_index = False) \
    .agg({'is_canceled' : 'count'}) \
    .rename(columns={'is_canceled':'canceled'})

# %%
cancelled_with_kids = bookings.query("is_canceled == '1' & has_kids == True")
cancelled_with_kids.shape
# Out:
# (3259, 23)

# %%
all_with_kids = bookings.query("has_kids == True")
all_with_kids.shape
# Out:
# (9332, 23)

# %%
churn_rate_with_kids = cancelled_with_kids.shape[0] / all_with_kids.shape[0]
round(churn_rate_with_kids,2)
# Out:
# 0.35

# %%
cancelled_without_kids = bookings.query("is_canceled == '1' & has_kids == False")
cancelled_without_kids.shape

all_without_kids = bookings.query("has_kids == False")
all_without_kids.shape

churn_rate_without_kids = cancelled_without_kids.shape[0] / all_without_kids.shape[0]*100
round(churn_rate_without_kids,2)
# Out:
# 37.22

# %%
def has_kids(x):
    if x > 0:
        return True
    else:
        return False

# %%
#Solution 1
bookings['has_kids'] = bookings.total_kids.apply(has_kids)
bookings['has_kids'].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: has_kids, dtype: bool

# %%
#Solution 2
bookings['has_kids'] = bookings.total_kids > 0
bookings['has_kids'].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: has_kids, dtype: bool

# %%
bookings['has_kids'] = bookings.total_kids.astype(bool)
bookings['has_kids'].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: has_kids, dtype: bool

# %%
bookings['has_kids']['is_canceled'].value_count
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-223-e6e2b885c3c9> in <module>
# ----> 1 bookings['has_kids']['is_canceled'].value_count
#
# D:\Anaconda\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
# ...
